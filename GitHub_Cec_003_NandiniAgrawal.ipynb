# %%
# Download a dataset from Kaggle
# For Ex. : HotelReservations.csv
# install the pandas library
# import the library
# Load csv file in jupyter notebook

# %%
# install the pandas library

pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the library

import pandas as pd

# %%
# Load csv file in jupyter notebook

df = pd.read_csv('HotelReservations.csv')
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
#Q1:  Fetch data from paticular column as : row(1) , column(1) 

df.loc[1]
# Out:
# Booking_ID                                  INN00002
# no_of_adults                                       2
# no_of_children                                     0
# no_of_weekend_nights                               2
# no_of_week_nights                                  3
# type_of_meal_plan                       Not Selected
# required_car_parking_space                         0
# room_type_reserved                       Room_Type 1
# lead_time                                          5
# arrival_year                                    2018
# arrival_month                                     11
# arrival_date                                       6
# market_segment_type                           Online
# repeated_guest                                     0
# no_of_previous_cancellations                       0
# no_of_previous_bookings_not_canceled               0
# avg_price_per_room                            106.68
# no_of_special_requests                             1
# ...

# %%
#Q2: Print length of rows

len(df)
# Out:
# 36275

# %%
# Q3: Print first 4 records of dataset  
df.head(4)
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# 1        Room_Type 1          5          2018             11             6
# ...

# %%
# Q4: First starting records of dataset  
# That will be generated randomly 

df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
# Q5: Print last records of dataset  

df.tail(2)
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 36273                  3      Not Selected                           0
# 36274                  2       Meal Plan 1                           0
#
#       room_type_reserved  lead_time  arrival_year  arrival_month  \
# 36273        Room_Type 1         63          2018              4
# 36274        Room_Type 1        207          2018             12
#
#        arrival_date market_segment_type  repeated_guest  \
# 36273            21              Online               0
# 36274            30             Offline               0
#
#        no_of_previous_cancellations  no_of_previous_bookings_not_canceled  \
# 36273                             0                                     0
# ...

# %%
#Q6: Fetch records of all Booking_ID

df.Booking_ID
# Out:
# 0        INN00001
# 1        INN00002
# 2        INN00003
# 3        INN00004
# 4        INN00005
#            ...
# 36270    INN36271
# 36271    INN36272
# 36272    INN36273
# 36273    INN36274
# 36274    INN36275
# Name: Booking_ID, Length: 36275, dtype: object

# %%
#Q7: Print First starting records from column Booking_ID of dataset  

df.Booking_ID.head()
# Out:
# 0    INN00001
# 1    INN00002
# 2    INN00003
# 3    INN00004
# 4    INN00005
# Name: Booking_ID, dtype: object

# %%
#Q7: Print first 2 records which have lead_time greater than 80

df.query('lead_time > 80').head(2)
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 3   INN00004             2               0                     0
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# 3        Room_Type 1        211          2018              5            20
#
#   market_segment_type  repeated_guest  no_of_previous_cancellations  \
# 0             Offline               0                             0
# 3              Online               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0                65.0
# ...

# %%
#Q8 : Print all the columns name

df.columns
# Out:
# Index(['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
#Q8 : Print the column name , index should be 2

df.columns[2]
# Out:
# 'no_of_children'

# %%
#Q9: Print first 10 records whose market_segment_type is equal to Offline 

df.query("market_segment_type == 'Offline' ").head(10)
# Out:
#    Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0    INN00001             2               0                     1
# 8    INN00009             3               0                     0
# 16   INN00017             1               0                     1
# 19   INN00020             2               0                     1
# 22   INN00023             2               0                     2
# 23   INN00024             2               0                     0
# 26   INN00027             2               0                     1
# 29   INN00030             2               0                     0
# 34   INN00035             2               0                     0
# 37   INN00038             2               0                     0
#
#     no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                   2       Meal Plan 1                           0
# 8                   4       Meal Plan 1                           0
# ...

# %%
#Q10: Fetch the records of rows at 0,3,5.

df.loc[[0,3,5]]
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 3   INN00004             2               0                     0
# 5   INN00006             2               0                     0
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 5                  2       Meal Plan 2                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# 3        Room_Type 1        211          2018              5            20
# 5        Room_Type 1        346          2018              9            13
#
#   market_segment_type  repeated_guest  no_of_previous_cancellations  \
# ...
